# %%
library(ensembldb)
library(AnnotationHub)
library(GenomicRanges)
ah <- AnnotationHub()

edb <- ah[["AH119325"]]
gene_symbol <- "ERBB2"
tx_df <- transcripts(
  edb,
  filter = GeneNameFilter(gene_symbol),
  return.type = "DataFrame"
)
tx_df
# Out:
# loading from cache
# DataFrame with 26 rows and 14 columns
#               tx_id             tx_biotype tx_seq_start tx_seq_end
#         <character>            <character>    <integer>  <integer>
# 1   ENST00000584601         protein_coding     39687914   39728361
# 2         LRG_724t1               LRG_gene     39688084   39728662
# 3         LRG_724t3               LRG_gene     39688084   39717657
# 4         LRG_724t4               LRG_gene     39688084   39728662
# 5   ENST00000584014        retained_intron     39688101   39695181
# ...             ...                    ...          ...        ...
# 22  ENST00000582818         protein_coding     39716551   39723950
# 23  ENST00000578630        retained_intron     39716974   39723968
# 24  ENST00000584684        retained_intron     39717343   39720297
# 25  ENST00000580074         protein_coding     39717429   39725203
# 26  ENST00000584888 protein_coding_CDS_n..     39728386   39730426
#     tx_cds_seq_start tx_cds_seq_end         gene_id tx_support_level
#            <integer>      <integer>     <character>        <integer>
# 1           39707007       39728044 ENSG00000141736                2
# 2           39707007       39728044         LRG_724               NA
# 3           39707007       39717484         LRG_724               NA
# 4           39699560       39728044         LRG_724               NA
# 5                 NA             NA ENSG00000141736                1
# ...              ...            ...             ...              ...
# 22          39716551       39723950 ENSG00000141736                3
# 23                NA             NA ENSG00000141736                2
# 24                NA             NA ENSG00000141736                3
# 25          39717429       39725203 ENSG00000141736                3
# 26                NA             NA ENSG00000141736                3
#         tx_id_version gc_content tx_external_name tx_is_canonical
#           <character>  <numeric>      <character>       <integer>
# 1   ENST00000584601.5    59.2863        ERBB2-219               0
# 2         LRG_724t1.1    58.1897               NA               1
# 3         LRG_724t3.1    56.7747               NA               0
# 4         LRG_724t4.1    58.1150               NA               0
# 5   ENST00000584014.5    49.7055        ERBB2-216               0
# ...               ...        ...              ...             ...
# 22  ENST00000582818.5    60.3025        ERBB2-213               0
# 23  ENST00000578630.1    58.1236        ERBB2-208               0
# 24  ENST00000584684.1    56.7026        ERBB2-220               0
# 25  ENST00000580074.1    57.1618        ERBB2-210               0
# 26  ENST00000584888.1    61.6000        ERBB2-221               0
#             tx_name   gene_name
#         <character> <character>
# 1   ENST00000584601       ERBB2
# 2         LRG_724t1       ERBB2
# 3         LRG_724t3       ERBB2
# 4         LRG_724t4       ERBB2
# 5   ENST00000584014       ERBB2
# ...             ...         ...
# 22  ENST00000582818       ERBB2
# 23  ENST00000578630       ERBB2
# 24  ENST00000584684       ERBB2
# 25  ENST00000580074       ERBB2
# 26  ENST00000584888       ERBB2

# %%
write.table(
  as.data.frame(tx_df),
  file = "transcripts.tsv",
  sep = "\t",
  row.names = FALSE,
  quote = FALSE
)
pr_df <- proteins(
  edb,
  filter = GeneNameFilter(gene_symbol),
  return.type = "DataFrame"
)
pr_df
# Out:
# DataFrame with 17 rows and 4 columns
#               tx_id      protein_id       protein_sequence   gene_name
#         <character>     <character>            <character> <character>
# 1   ENST00000584601 ENSP00000462438 MKLRLPASPETHLDMLRHLY..       ERBB2
# 2   ENST00000578199 ENSP00000462808 MKLRLPASPETHLDMLRHLY..       ERBB2
# 3   ENST00000406381 ENSP00000385185 MKLRLPASPETHLDMLRHLY..       ERBB2
# 4   ENST00000541774 ENSP00000446466 MPRGSWKPQVCTGTDMKLRL..       ERBB2
# 5   ENST00000445658 ENSP00000404047 MELAALCRWGLLLALLPPGA..       ERBB2
# ...             ...             ...                    ...         ...
# 13  ENST00000580074 ENSP00000463002 XPDEEGACQPCPINCTHSPL..       ERBB2
# 14        LRG_724t1       LRG_724p1 MKLRLPASPETHLDMLRHLY..       ERBB2
# 15        LRG_724t2       LRG_724p2 MELAALCRWGLLLALLPPGA..       ERBB2
# 16        LRG_724t3       LRG_724p3 MKLRLPASPETHLDMLRHLY..       ERBB2
# 17        LRG_724t4       LRG_724p4 MPRGSWKPQVCTGTDMKLRL..       ERBB2

# %%
write.table(
  as.data.frame(pr_df),
  file = "proteins.tsv",
  sep = "\t",
  row.names = FALSE,
  quote = FALSE
)
dir.create("protein_maps", showWarnings = FALSE)

for (i in seq_len(nrow(pr_df))) {

  pid  <- pr_df$protein_id[i]

  pseq <- pr_df$protein_sequence[i]

  if (is.na(pid) || is.na(pseq) || nchar(pseq) == 0)
    next

  rng <- IRanges(
    start = 1,
    end = nchar(pseq),
    names = pid
  )

  map <- proteinToGenome(rng, edb)[[1]]

  write.table(
    as.data.frame(map),
    file = file.path(
      "protein_maps",
      paste0(pid, "_map.tsv")
    ),
    sep = "\t",
    row.names = FALSE,
    quote = FALSE
  )
}
getwd()
# Out:
# Fetching CDS for 1 proteins ...
# 1 found
#
# Checking CDS and protein sequence lengths ...
# 1/1 OK
#
# Fetching CDS for 1 proteins ...
# 1 found
#
# Checking CDS and protein sequence lengths ...
# 1/1 OK
#
# Fetching CDS for 1 proteins ...
# 1 found
#
# Checking CDS and protein sequence lengths ...
# 1/1 OK
#
# Fetching CDS for 1 proteins ...
# 1 found
#
# Checking CDS and protein sequence lengths ...
# 1/1 OK
#
# Fetching CDS for 1 proteins ...
# 1 found
#
# Checking CDS and protein sequence lengths ...
# 1/1 OK
#
# Fetching CDS for 1 proteins ...
# 1 found
#
# Checking CDS and protein sequence lengths ...
# 1/1 OK
#
# Fetching CDS for 1 proteins ...
# 1 found
#
# Checking CDS and protein sequence lengths ...
# 1/1 OK
#
# Fetching CDS for 1 proteins ...
# 1 found
#
# Checking CDS and protein sequence lengths ...
# 1/1 OK
#
# Fetching CDS for 1 proteins ...
# 1 found
#
# Checking CDS and protein sequence lengths ...
# 1/1 OK
#
# Fetching CDS for 1 proteins ...
# 1 found
#
# Checking CDS and protein sequence lengths ...
# Warning message:
# "Could not find a CDS whith the expected length for protein: 'ENSP00000463719'. The returned genomic coordinates might thus not be correct for this protein."
# 0/1 OK
#
# Fetching CDS for 1 proteins ...
# Warning message in .local(x, db, ...):
# "No CDS found for: ENSP00000464420"
# 0 found
#
# Checking CDS and protein sequence lengths ...
# 0/1 OK
#
# Fetching CDS for 1 proteins ...
# Warning message in .local(x, db, ...):
# "No CDS found for: ENSP00000464252"
# 0 found
#
# Checking CDS and protein sequence lengths ...
# 0/1 OK
#
# Fetching CDS for 1 proteins ...
# 1 found
#
# Checking CDS and protein sequence lengths ...
# Warning message:
# "Could not find a CDS whith the expected length for protein: 'ENSP00000463002'. The returned genomic coordinates might thus not be correct for this protein."
# 0/1 OK
#
# Fetching CDS for 1 proteins ...
# 1 found
#
# Checking CDS and protein sequence lengths ...
# 1/1 OK
#
# Fetching CDS for 1 proteins ...
# 1 found
#
# Checking CDS and protein sequence lengths ...
# 1/1 OK
#
# Fetching CDS for 1 proteins ...
# 1 found
#
# Checking CDS and protein sequence lengths ...
# 1/1 OK
#
# Fetching CDS for 1 proteins ...
# 1 found
#
# Checking CDS and protein sequence lengths ...
# 1/1 OK
# [1] "/content"
